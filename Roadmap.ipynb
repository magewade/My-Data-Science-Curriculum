# %% [markdown]
# ✅ - пройдено
#
# 🟡 - пауза или в процессе
#
# ### DataCamp:
#
# [https://app.datacamp.com](https://app.datacamp.com/)
#
# **Career tracks:**
#
# - Associate Data Scientist in Python https://app.datacamp.com/learn/career-tracks/associate-data-scientist-in-python 🟡
# - Data Scientist in Python https://app.datacamp.com/learn/career-tracks/data-scientist-in-python
# - Machine Learning Scientist in Python https://app.datacamp.com/learn/career-tracks/machine-learning-scientist-with-python
#
# ### Начальный этап / Foundational Stage:
#
# 1. **Программирование / Programming:**
#     - Изучение Python, включая основные структуры данных и управляющие конструкции / Learning Python (or another programming language), including basic data structures and control flow
#         - "Поколение Python": курс для начинающих https://stepik.org/course/58852/syllabus ✅
#         - "Поколение Python": курс для продвинутых https://stepik.org/course/68343/info ✅
#         - "Поколение Python": курс для профессионалов https://stepik.org/course/82541/syllabus ✅
#         - Продвинутый python: заряди свои батарейки https://stepik.org/course/127822/syllabus
#     - ООП / OOP
#         - "Поколение Python": ООП https://stepik.org/course/98974/syllabus 🟡
#         - Добрый, добрый Python ООП - обучающий курс от Сергея Балакирева https://stepik.org/course/116336/syllabus
#     - Алгоритмы и многопоточное программирование / Algorithms and multithreaded programming
#         - Многопоточный Python https://stepik.org/course/190100/syllabus
#         - Многопоточность в Python. Multithreading https://stepik.org/course/172356/syllabus
#         - Асинхронный Python https://stepik.org/course/170777/syllabus
#         - Алгоритмы на Python https://stepik.org/course/57382/promo
#     - Другое / Other
#         - Регулярные выражения в Python https://stepik.org/course/107335/syllabus
#         - FastAPI — основы backend разработки на Python https://stepik.org/lesson/1242214/step/1?unit=1255978
# 2. **Основы математики и статистики / Mathematical Foundations:**
#     - Линейная алгебра / Linear Algebra
#         - https://www.khanacademy.org/math/linear-algebra
#         - https://www.khanacademy.org/math/cc-eighth-grade-math/cc-8th-linear-equations-functions
#     - Дифференциальное и интегральное исчисление / Calculus
#         - https://www.khanacademy.org/math/differential-calculus
#         - https://www.khanacademy.org/math/integral-calculus
#         - https://www.khanacademy.org/math/multivariable-calculus
#     - Теория вероятностей и статистика / Probability Theory and Statistics
#         - https://www.khanacademy.org/math/cc-seventh-grade-math/cc-7th-probability-statistics
#     - A/B Testing
#     - OR:
#         - Подготовка к экзамену по математике в магистратуру https://stepik.org/course/141321/syllabus
#         - Математика для Data Science. Специализация. Тариф «Перельман» https://stepik.org/course/93964/syllabus ✅
#             - 1 часть Математический анализ https://stepik.org/course/94351/syllabus ✅
#             - 2 часть Линейная алгебра https://stepik.org/course/96146/syllabus ✅
#             - 3 часть Теорвер https://stepik.org/course/112072/syllabus ✅
#             - 4 часть Статистика https://stepik.org/lesson/650426/step/2?unit=713344 ✅
#         - https://www.youtube.com/@3blue1brown31 - 3Blue1Brown https://www.youtube.com/@3blue1brown на русском
# 3. **Основы ML / ML Basics:**
#     - Введение в ML и его применения в различных областях / Introduction to ML and its applications across various domains Введение в Data Science и машинное обучение https://stepik.org/course/4852/syllabus ✅
#     - Типы задач ML: классификация, регрессия, кластеризация. Оценка производительности моделей ML / Types of ML tasks: classification, regression, clustering. Methods for evaluating ML model performance
#         - Практический Machine Learning https://stepik.org/course/125501/syllabus 🟡
# 4. **Data Base**
#     - SQL
#         - SQLAlchemy — продвинутая работа с базой данных через Python https://stepik.org/lesson/1170408/step/1?unit=1182795
#         - **СИМУЛЯТОР SQL** https://karpov.courses/simulator-sql
#     - ETL Processes/ACID Principles
#     - Big Data/Data Storage
#
# ### Продвинутый этап / Advanced Stage:
#
# 1. **Обработка и предварительная подготовка данных / Data Processing and Preparation:**
#     - Очистка данных: обработка пропущенных значений, устранение выбросов / Data cleaning: handling missing values, removing outliers
#     - Масштабирование данных: стандартизация, нормализация / Data scaling: standardization, normalization
#     - Инженерия признаков: создание новых признаков на основе существующих / Feature engineering: creating new features based on existing ones
#         - Разведочный анализ данных https://stepik.org/course/177213/syllabus ✅
# 2. **Методы машинного обучения / Machine Learning Methods:**
#     - Линейные модели: линейная регрессия, логистическая регрессия / Linear Models: linear regression, logistic regression
#         - Линейные модели и их презентация https://stepik.org/course/177215/syllabus 🟡
#     - Деревья решений и ансамбли: случайный лес, градиентный бустинг / Decision Trees and Ensembles: random forest, gradient boosting
#     - Нейронные сети: многослойные перцептроны, сверточные нейронные сети, рекуррентные нейронные сети / Neural Networks: multilayer perceptrons, convolutional neural networks, recurrent neural networks
#         - Практический Deep Learning https://stepik.org/course/179805/syllabus
#         - Введение в соревновательный Data Science https://stepik.org/course/108888/syllabus
#
# ### Специализация / Specialization:
#
# 1. **Оптимизация моделей и гиперпараметры / Model Optimization and Hyperparameter Tuning:**
#     - Подбор гиперпараметров моделей ML / Hyperparameter tuning for ML models
#     - Оптимизация и регуляризация моделей / Model optimization and regularization
#     - Построение кривых обучения и валидации / Constructing learning and validation curves.
#         - Продвинутые методы машинного обучения https://stepik.org/course/175967/syllabus
#         - Временные ряды для прогноза криптовалют https://stepik.org/course/177216/syllabus
#         - Разработка ML сервиса: от идеи к прототипу https://stepik.org/course/176820/syllabus
# 2. **Обработка текстов и изображений / Text and Image Processing:**
#     - NLP (Natural Language Processing): токенизация, векторизация текста, анализ тональности / NLP (Natural Language Processing): tokenization, text vectorization, sentiment analysis.
#         - First Step in NLP 2.0 https://stepik.org/course/129443/syllabus
#         - Second Step in NLP https://stepik.org/course/133963/syllabus
#         - Нейронные сети и обработка текста https://stepik.org/course/54098/syllabus
#         - Основы нейронных сетей и NLP https://stepik.org/course/180984/syllabus
#         - Рекуррентные сети в NLP и приложениях https://stepik.org/course/188632/promo
#         - Трансформеры в NLP и приложениях https://stepik.org/course/193305/promo
#     - CV (Computer Vision): обработка изображений, классификация объектов / CV (Computer Vision): image processing, object classification.
#         - Нейронные сети и компьютерное зрение https://stepik.org/course/50352/syllabus
# 3. **Методы глубокого обучения / Deep Learning Methods:**
#     - Сверточные нейронные сети (CNN) / Convolutional Neural Networks (CNN)
#     - Рекуррентные нейронные сети (RNN) / Recurrent Neural Networks (RNN)
#     - Генеративные нейронные сети (GAN) / Generative Adversarial Networks (GAN)
#         - https://stepik.org/lesson/825860/step/1?unit=829387
#
#
# ### DevOps things:
#
# 1. **Cloud, Ops**
# - GCP
# - Azure
# - AWS
# - MLOps  https://stepik.org/course/181476/syllabus
# - ClearML/KubeML
# - Hadoop
# - Docker/Composer/Kubernetes
#     - DOCKER С НУЛЯ https://karpov.courses/docker
#
# 1. **Overall IT**
# - Git
# - Agile Methodology
# - CI/CD Concept
#     - Gitlab в работе https://stepik.org/course/118206/promo?search=2719122560
# - Algorithms and Data Structures Алгоритмы и структуры данных https://shultais.education/courses/algo
# - Console Основы командной строки https://ru.hexlet.io/courses/cli-basics
#
# ### Практика и проекты / Practice and Projects:
#
# 1. **Реальные проекты / Real-world Projects:**
# - Участие в соревнованиях по анализу данных (например, на Kaggle) / Participating in Data Analysis Competitions (e.g., Kaggle)
#
# ### Для общего развития / Additional Resources:
#
# 1. **Литература и дополнительно / Literature and Additional:**
# - Телеграм-боты на Python и AIOgram https://stepik.org/course/120924/syllabus
# - Проверка гипотез и анализ данных на Python https://stepik.org/course/193096/promo
# - Apache Airflow для аналитика https://stepik.org/course/99527/info
# - Экспресс-курс Greenplum для аналитиков и разработчиков https://stepik.org/course/174901/promo
# - ClickHouse для аналитика https://stepik.org/course/100210/promo
# - Парсинг https://stepik.org/course/104774/promo?search=3853357436
# - https://ru.hexlet.io/webinars
#
# https://roadmap.sh/ai-data-scientist
